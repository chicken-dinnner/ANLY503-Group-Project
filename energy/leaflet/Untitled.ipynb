# %%
import pandas as pd

# %%
a = pd.read_csv('energy.csv')

# %%
b = pd.read_csv('mydata.csv')

# %%
a.head()
# Out:
#          NAME  crude_oil_production  crude_oil_consumption  gas_production  \
# 0     Belgium                     0                     36               0
# 1  Czech Rep.                     0                      8               0
# 2      France                     1                     60               0
# 3     Germany                     4                    101               7
# 4       Italy                     6                     73               6
#
#    gas_consumption  coal_production  coal_consumption  renew_share  \
# 0               18                0                 4        18.65
# 1                9               45                45        12.45
# 2               45                0                15        17.56
# 3               94              175               222        33.98
# 4               75                0                15        35.74
#
#    energy_intensity  co2_intensity  crude_oil_balance  gas_balance  \
# ...

# %%
b.head()
# Out:
#    Unnamed: 0 FIPS ISO2 ISO3  UN                 NAME    AREA    POP2005  \
# 0           0   AC   AG  ATG  28  Antigua and Barbuda      44   0.083039
# 1           1   AG   DZ  DZA  12              Algeria  238174  32.854159
# 2           2   AJ   AZ  AZE  31           Azerbaijan    8260   8.352021
# 3           3   AL   AL  ALB   8              Albania    2740   3.153731
# 4           4   AM   AM  ARM  51              Armenia    2820   3.017661
#
#    REGION  SUBREGION     LON     LAT
# 0      19         29 -61.783  17.078
# 1       2         15   2.632  28.163
# 2     142        145  47.395  40.430
# 3     150         39  20.068  41.143
# 4     142        145  44.563  40.534

# %%
c = pd.merge(b, a, on='NAME', how='left')

# %%
c.head()
# Out:
#    Unnamed: 0 FIPS ISO2 ISO3  UN                 NAME    AREA    POP2005  \
# 0           0   AC   AG  ATG  28  Antigua and Barbuda      44   0.083039
# 1           1   AG   DZ  DZA  12              Algeria  238174  32.854159
# 2           2   AJ   AZ  AZE  31           Azerbaijan    8260   8.352021
# 3           3   AL   AL  ALB   8              Albania    2740   3.153731
# 4           4   AM   AM  ARM  51              Armenia    2820   3.017661
#
#    REGION  SUBREGION      ...       gas_production  gas_consumption  \
# 0      19         29      ...                  NaN              NaN
# 1       2         15      ...                 95.0             41.0
# 2     142        145      ...                  NaN              NaN
# 3     150         39      ...                  NaN              NaN
# 4     142        145      ...                  NaN              NaN
#
#    coal_production  coal_consumption  renew_share  energy_intensity  \
# ...

# %%
c.to_csv('combine.csv',sep=',')

# %%
c=c.fillna(0)

# %%
c.to_csv('combine.csv',sep=',')
